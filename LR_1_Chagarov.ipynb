# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %% [markdown]
# #Практическое задание №1
#
# **Студенческие** *будни*
#
# Маркированный список:
#
# *   Лабораторная работа 1
# *   Лабораторная работа 2
#
# Нумерованный список:
#
# 1.   Практическое занятие 1
# 2.   Практическое занятие 2
#
# Формула: $ (d/dx) * ln(x) = (1/x)$
#
# ![Формула для производной функции логарифма:](https://i0.wp.com/www.goseeko.com/blog/wp-content/uploads/2022/04/close-up-image-programer-working-his-desk-office.jpg?fit=7360%2C4912&ssl=1)

# %%
name = input()
print("Привет,", name, "! Добро пожаловать в JupyterLab / Google Colab!")
# Out:
# Аслан
# Привет, Аслан ! Добро пожаловать в JupyterLab / Google Colab!

# %% [markdown]
# # Заголовок первого уровня
# ## Заголовок второго уровня
# **Жирный текст**, *курсив*, `код`
# Список:
# - Пункт 1
# - Пункт 2
# Формула: $y = mx + b$

# %%
import os

with open("report.txt", "w") as f:
  f.write("Лабораторная 1 выполнена\n")
  f.write("Лабораторная 2 на очереди\n")

with open("report.txt", "r") as f:
  content = f.read()
  print("Содержимое файла:\n", content)

  print("Файл существует:", os.path.exists("report.txt"))

os.remove("report.txt")
print("Файл удален.")
# Out:
# Содержимое файла:
#  Лабораторная 1 выполнена
# Лабораторная 2 на очереди
#
# Файл существует: True
# Файл удален.

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %time
print('Hello, Jupyter')
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# Hello, Jupyter

# %%
# %%timeit
print('Hello, Jupyter')
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# Hello, Jupyter
# ...

# %%
# %%writefile script.py
print('Hello, Jupyter')
# Out:
# Writing script.py

# %%
# !python script.py
# Out:
# Hello, Jupyter

# %%
# %ls
# Out:
# sample_data/  script.py  test_script.py

# %%
# %history
# Out:
# name = input()
# print("Привет," name "! Добро пожаловать в JupyterLab / Google Colab!")
# name = input()
# print("Привет,", name, "! Добро пожаловать в JupyterLab / Google Colab!")
# import os
#
# with open("report.txt", "w") as f:
#   f.write("Лабораторная 1 выполнена\n")
#   f.write("Лабораторная 2 на очереди\n")
#
# with open("report.txt", "r") as f:
#   content = f.read()
#   print("Содержимое файла:\n", content)
#
#   print("Файл существует:", os.path.exists("report.txt"))
#
# os.remove("report.txt")
# print("Файл удален.")
# %%writefile test_script.py
# for i in range(3):
#   print(f"Итерация {i}")
#
# !python test_script.py
#
# %time sum(range(1000000))
# %%writefile test_script.py
# %lsmagic
# %lsmagic
# %time
# %%timeit
# %time
# print('Hello, Jupyter')
# %%timeit
# print('Hello, Jupyter')
# %%writefile script.py
# print('Hello, Jupyter')
# !python script.py
# %ls
# %history

# %%
# !ls
# Out:
# sample_data  script.py	test_script.py

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !mkdir test_folder

# %%
# !rmdir test_folder

# %%
# !clear

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls/content/drive/MyDrive
# Out:
# /bin/bash: line 1: ls/content/drive/MyDrive: No such file or directory

# %%
file_path = "/content/drive/MyDrive/my_text_file.txt"
with open(file_path, "w") as f:
  f.write("Первый текстовый файл\n")
  f.write("Вторая строка текстового файла.")

print("Файл успешно сохранен в Google Drive.")
# Out:
# Файл успешно сохранен в Google Drive.

# %%
with open(file_path, "r") as f:
  content = f.read()
print("Содержимое файла:\n", content)
# Out:
# Содержимое файла:
#  Первый текстовый файл
# Вторая строка текстового файла.

# %%
students = [
  ["Кочкаров Э.", 19, "ИВТ-б-о-23-3"],
  ["Мальсагов И.", 20, "ИВТ-б-о-23-3"],
  ["Чагаров А.", 19, "ИВТ-б-о-23-3"]
]

csv_path = "/content/drive/MyDrive/students.csv"
with open(csv_path, "w") as f:
  for student in students:
    f.write(",".join(map(str, student)) + "\n")
print("Файл students.csv успешно сохранен в Google Drive.")
# Out:
# Файл students.csv успешно сохранен в Google Drive.
